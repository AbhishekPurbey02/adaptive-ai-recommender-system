# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('../data/amazon_products.csv',nrows=50000)
print("Data loaded!")
print(f"Rows: {len(dataset)}")
print(f"Columns: {dataset.columns.to_list()}")
print(dataset.head())
# Out:
# Data loaded!
# Rows: 50000
# Columns: ['asin', 'title', 'imgUrl', 'productURL', 'stars', 'reviews', 'price', 'listPrice', 'category_id', 'isBestSeller', 'boughtInLastMonth']
#          asin                                              title  \
# 0  B014TMV5YE  Sion Softside Expandable Roller Luggage, Black...
# 1  B07GDLCQXV  Luggage Sets Expandable PC+ABS Durable Suitcas...
# 2  B07XSCCZYG  Platinum Elite Softside Expandable Checked Lug...
# 3  B08MVFKGJM  Freeform Hardside Expandable with Double Spinn...
# 4  B01DJLKZBA  Winfield 2 Hardside Expandable Luggage with Sp...
#
#                                               imgUrl  \
# 0  https://m.media-amazon.com/images/I/815dLQKYIY...
# 1  https://m.media-amazon.com/images/I/81bQlm7vf6...
# 2  https://m.media-amazon.com/images/I/71EA35zvJB...
# 3  https://m.media-amazon.com/images/I/91k6NYLQyI...
# 4  https://m.media-amazon.com/images/I/61NJoaZcP9...
#
#                              productURL  stars  reviews   price  listPrice  \
# 0  https://www.amazon.com/dp/B014TMV5YE    4.5        0  139.99       0.00
# 1  https://www.amazon.com/dp/B07GDLCQXV    4.5        0  169.99     209.99
# 2  https://www.amazon.com/dp/B07XSCCZYG    4.6        0  365.49     429.99
# 3  https://www.amazon.com/dp/B08MVFKGJM    4.6        0  291.59     354.37
# 4  https://www.amazon.com/dp/B01DJLKZBA    4.5        0  174.99     309.99
#
#    category_id  isBestSeller  boughtInLastMonth
# 0          104         False               2000
# 1          104         False               1000
# 2          104         False                300
# 3          104         False                400
# 4          104         False                400

# %%
# Basic dataset info
print("=== Dataset INFO ===\n")
print(f"Rows: {len(dataset)}")
print(f"Columns: {len(dataset.columns)}")
print(f"\n Missing values: \n {dataset.isnull().sum()}")
# Out:
# === Dataset INFO ===
#
# Rows: 50000
# Columns: 11
#
#  Missing values:
#  asin                 0
# title                0
# imgUrl               0
# productURL           0
# stars                0
# reviews              0
# price                0
# listPrice            0
# category_id          0
# isBestSeller         0
# boughtInLastMonth    0
# dtype: int64

# %%
# Rating Distrubution (Stars)
print("=== Rating Distribution ===\n")
print(dataset['stars'].value_counts())
# Out:
# === Rating Distribution ===
#
# stars
# 4.5    7622
# 4.4    6533
# 4.6    6238
# 4.3    5283
# 4.7    3852
# 4.2    3745
# 0.0    3091
# 5.0    2778
# 4.1    2584
# 4.0    1942
# 4.8    1676
# 3.9    1121
# 3.8     799
# 3.7     536
# 4.9     434
# 3.6     373
# 3.5     321
# 3.4     202
# 3.0     182
# 3.3     173
# 1.0     116
# 3.2      87
# 3.1      81
# 2.0      59
# 2.8      33
# 2.9      29
# 2.5      29
# 2.7      21
# 2.6      14
# 2.4      11
# 2.3       9
# 2.2       9
# 2.1       7
# 1.5       5
# 1.9       5
# Name: count, dtype: int64

# %%
# Popular Producst
print("=== Top 10  Most Popular  Products ===\n")
popular = dataset.nlargest(10, 'boughtInLastMonth')[['title', 'boughtInLastMonth', 'stars', 'price']]
print(popular)
# Out:
# === Top 10  Most Popular  Products ===
#
#                                                   title  boughtInLastMonth  \
# 924      Men's Eversoft Cotton Stay Tucked Crew T-Shirt              10000
# 946   mens 12 Pair Pack Dual Defense Cushioned Casua...               9000
# 927   Men's Boxer Briefs, Soft and Breathable Cotton...               8000
# 933         Men's Crew T-Shirts, Multipack, Style G1100               8000
# 934   Nxtrnd XTD Scrunch Football Socks, Extra Long ...               8000
# 926   Performance Lightweight Crew Training Socks (3...               7000
# 928   Hooded Rain Poncho for Adult with Pocket, Wate...               7000
# 929                 Unisex Everyday Cushion Crew 3 Pair               7000
# 940            Ultra-lite2 Waterproof Breathable Poncho               7000
# 1084                                  Men's Storm Liner               7000
#
#       stars  price
# 924     4.6  18.48
# 946     4.7  15.49
# 927     4.6  21.98
# 933     4.6  18.99
# 934     4.7  19.95
# 926     4.7  17.90
# 928     4.6  16.95
# 929     4.6  17.99
# 940     4.5  12.69
# 1084    4.7  13.28
